# %% [markdown]
# <a href="https://colab.research.google.com/github/roderickperez/DCA_using_RNN/blob/master/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shell.AI

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
