# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Link the Google Drive folder where results will be saved
# !ln -s /content/drive/MyDrive/Sentinel2A_AI

# %%
# Install the S2DR3 package for Sentinel-2 image processing
# !pip -q install https://storage.googleapis.com/0x7ff601307fa5/s2dr3-20250905.1-cp312-cp312-linux_x86_64.whl
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 77.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 90.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.5 MB/s eta 0:00:00

# %%
import s2dr3.inferutils

# %%
# Coordinates of Chennai, India (longitude, latitude)
lonlat = (16.00983, 46.91087)

# %%
# Date of the Sentinel-2 image to process
date = '2025-03-20'

# %%
# Process the image and generate 1m resolution products
s2dr3.inferutils.test(lonlat, date)
# Out:
# Fetching model: 100%|██████████| 829M/829M [00:20<00:00, 40.3MiB/s]
# Fetching data for T33TWM-d4af60d69-20250320 .......... done.
# Processing S2L2A_T33TWM-d4af60d69-20250320_MS . done
# Postprocessing S2L2A_T33TWM-d4af60d69-20250320_MS ......... done
#
# Find results at the following path: /content/output
# Click the link below for preview:
#
# https://gamayos.github.io/gamma-earth-api/s2dr3-demo-20250305.html?ds=AT-T33TWM-d4af60d69-20250320#15/46.9109/16.0098
